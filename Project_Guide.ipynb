# %% [markdown]
# 1. Create the GitHub repository for the project.
#
# ![image.png](attachment:image.png)
#
#
# 2. Clone the GitHub repo into your working environment.
# `git clone https://github.com/sMathujan/Tweet-Crafter.git`
#
#
# 3. Folder structure after clone the repository.
#
# ![image-2.png](attachment:image-2.png)
#
#
# 4. Create the conda environment for the project.
# `conda create -n tweet-crafter python=3.12`
#
#
# 5. Activate the conda environment.
# `conda activate tweet-crafter`
#
#
# 6. Install crewai.
# `pip install crewai`
#
#
# 7. Create the crew using CrewAI CLI.
# `crewai create tweetcrafter-crew`
#
#
# 8. Folder structure after the crew created by the CrewAI CLI.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
#
# 9. Re-arrange the folder strcture. Folder structure needed for the project.
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
# 10. Define the tasks inside tasks.yaml file.
#
#
# 11.
